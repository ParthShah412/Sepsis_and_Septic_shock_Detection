# %%
# Cell 3 documents example code to read in selected channgels in records, as well as ways to access the signal in ndarray
# Cell 40 shows how we can read in all channgels at once, and then seperate out specific signals

# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import shutil

import wfdb

# %%
recordlongn_mod = wfdb.rdrecord("p000020-2183-04-28-17-47n", channels= [0])
wfdb.plot_wfdb(record= recordlongn_mod, title= "longn_mod", annotation= None, figsize=(10,30), return_fig=False)
#wfdb.rdsamp(record_name= "p000020-2183-04-28-17-47n", channel_names=None)

display(recordlongn_mod.p_signal)
a= recordlongn_mod.p_signal
print (a)
print(type(a))
print(type(a[0]))
print(a[0])
print(a[:5, 0])
# Out:
# array([[ 98.6],
#        [ 80.1],
#        [ 80. ],
#        ...,
#        [ 72.3],
#        [ 73.8],
#        [ 74.9]])
# [[ 98.6]
#  [ 80.1]
#  [ 80. ]
#  ...,
#  [ 72.3]
#  [ 73.8]
#  [ 74.9]]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [ 98.6]
# [ 80.1  80.   80.   80. ]

# %%
recordlongn_mod = wfdb.rdrecord("p000020-2183-04-28-17-47n", channels= [0])
#print (recordlongn_mod.__dict__)
asdf= recordlongn_mod.p_signal
print (asdf)
wfdb.plot_items(signal= asdf, fs= 1 )#, time_units= "seconds")
# wfdb.plot_items(signal= asdf, fs= 1, time_units= "seconds")
# wfdb.plot_items(signal= asdf, fs= 1, time_units= "minutes")
# wfdb.plot_items(signal= asdf, fs= 200, time_units= "minutes")
# Out:
# [[ 98.6]
#  [ 80.1]
#  [ 80. ]
#  ...,
#  [ 72.3]
#  [ 73.8]
#  [ 74.9]]

# %%
testrecord= wfdb.rdrecord("p000020-2183-04-28-17-47n")
testrecord.__dict__
qwer= testrecord.p_signal[:, 0]
qwer== asdf.flatten()
# Out:
# array([ True,  True,  True, ...,  True,  True,  True], dtype=bool)
